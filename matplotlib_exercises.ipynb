# %%
#import libraries/modules

#import pyplot module as alias plt
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# y=(x * x)−x+2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = range(-10,10)

y = [n ** 2 - n + 2 for n in x]

plt.plot(x,y)



plt.annotate('The Origin', xy = (0, 0), xytext = (2, 38), arrowprops = dict(facecolor = 'gray'))

plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y = sqrt.x
#
# y = x ** 3
#
# y = 2 ** x
#
# y = 1/(x+1)
#
# You can use functions from the math module to help implement some of the equations above.

# %%
x = range(0,50)

y = [math.sqrt(n) for n in x]

plt.plot(x,y)

plt.show()

# %%
x = range(-10,10)

y = [n ** 3 for n in x]

plt.plot(x,y)

plt.show()

# %%
x = range(-10,10)

y = [2 ** n for n in x]

plt.plot(x,y)

plt.show()

# %%
x = range(1,10)

y = [1 / (n + 1) for n in x]

plt.plot(x,y)

plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.subplot(2,2,1)
x = range(0,50)

y = [math.sqrt(n) for n in x]

plt.plot(x,y)




plt.subplot(2,2,2)
x = range(-10,10)

y = [n ** 3 for n in x]

plt.plot(x,y)




plt.subplot(2,2,3)
x = range(-10,10)

y = [2 ** n for n in x]

plt.plot(x,y)





plt.subplot(2,2,4)
x = range(1,10)

y = [1 / (n + 1) for n in x]

plt.plot(x,y)

plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(14, 6))


plt.subplot(2,2,1)
x = range(0,50)

y = [math.sqrt(n) for n in x]

plt.plot(x,y, color='red', label='sqrt.x')

plt.legend()


plt.subplot(2,2,2)
x = range(-10,10)

y = [n ** 3 for n in x]

plt.plot(x,y, color='green', label ='x^3')

plt.legend()


plt.subplot(2,2,3)
x = range(-10,10)

y = [2 ** n for n in x]

plt.plot(x,y, color='yellow', label='2^n')


plt.legend()


plt.subplot(2,2,4)
x = range(1,10)

y = [1 / (n + 1) for n in x]

plt.plot(x,y, color='pink', label='1/(x+1)')

plt.legend()

plt.show()
