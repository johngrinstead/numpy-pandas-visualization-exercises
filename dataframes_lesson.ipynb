# %%
import pandas as pd

import numpy as np

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
print(df)
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# # Summarizing Dataframes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
df.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %% [markdown]
# # Dataframe Attributes

# %%
df.dtypes
# Out:
# name       object
# math        int64
# english     int64
# reading     int64
# dtype: object

# %%
df.shape
# Out:
# (12, 4)

# %%
df.columns
# Out:
# Index(['name', 'math', 'english', 'reading'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.columns = [col.upper() for col in df.columns]

#will uppercase the letters of title of each coloumn

# %%
df
# Out:
#        NAME  MATH  ENGLISH  READING
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# # Subsetting Dataframes

# %% [markdown]
# ## Accessing Multiple Columns

# %%
df[['name', 'math']]

#will only return the columns specified
# Out:
#        name  math
# 0     Sally    62
# 1      Jane    88
# 2     Suzie    94
# 3     Billy    98
# 4       Ada    77
# 5      John    79
# 6    Thomas    82
# 7     Marie    93
# 8    Albert    92
# 9   Richard    69
# 10    Isaac    92
# 11     Alan    92

# %%
columns = ['name', 'math']
df[columns]
# Out:
#        name  math
# 0     Sally    62
# 1      Jane    88
# 2     Suzie    94
# 3     Billy    98
# 4       Ada    77
# 5      John    79
# 6    Thomas    82
# 7     Marie    93
# 8    Albert    92
# 9   Richard    69
# 10    Isaac    92
# 11     Alan    92

# %% [markdown]
# ## Accessing Individual Columns

# %%
df.math

#will only return THE column specified
# Out:
# 0     62
# 1     88
# 2     94
# 3     98
# 4     77
# 5     79
# 6     82
# 7     93
# 8     92
# 9     69
# 10    92
# 11    92
# Name: math, dtype: int64

# %%
df['math']
# Out:
# 0     62
# 1     88
# 2     94
# 3     98
# 4     77
# 5     79
# 6     82
# 7     93
# 8     92
# 9     69
# 10    92
# 11    92
# Name: math, dtype: int64

# %% [markdown]
# ## Accessing Row Subsets

# %%
df.head()

#will show beginning of table, without a specified number it will default to 5 every time
# Out:
#     name  math  english  reading
# 0  Sally    62       85       80
# 1   Jane    88       79       67
# 2  Suzie    94       74       95
# 3  Billy    98       96       88
# 4    Ada    77       92       98

# %%
df.tail(3)
# Out:
#        name  math  english  reading
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.sample(4)

# .sample(n) will provide random rows of a specified amount
# Out:
#      name  math  english  reading
# 7   Marie    93       63       90
# 11   Alan    92       62       72
# 1    Jane    88       79       67
# 4     Ada    77       92       98

# %%
df.math < 80

#you can use comparison operators to return bool values
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# Name: math, dtype: bool

# %%
df[df.math < 80]
# Out:
#       name  math  english  reading
# 0    Sally    62       85       80
# 4      Ada    77       92       98
# 5     John    79       76       93
# 9  Richard    69       80       94

# %% [markdown]
# # Dropping and Renaming Columns

# %%
df.drop(columns=['english', 'reading'])

#will remove specified columns from table
# Out:
#        name  math
# 0     Sally    62
# 1      Jane    88
# 2     Suzie    94
# 3     Billy    98
# 4       Ada    77
# 5      John    79
# 6    Thomas    82
# 7     Marie    93
# 8    Albert    92
# 9   Richard    69
# 10    Isaac    92
# 11     Alan    92

# %%
df.rename(columns={'name': 'student'})

#will rename the specified column
# Out:
#     student  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df

#unless saved to a variable, nothing will be actually changed in the original table
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.drop(columns=['english', 'reading']).rename(columns={'name': 'student'})

#you can combine the operations
# Out:
#     student  math
# 0     Sally    62
# 1      Jane    88
# 2     Suzie    94
# 3     Billy    98
# 4       Ada    77
# 5      John    79
# 6    Thomas    82
# 7     Marie    93
# 8    Albert    92
# 9   Richard    69
# 10    Isaac    92
# 11     Alan    92

# %% [markdown]
# # Creating New Columns

# %%
df.math >= 70
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# Name: math, dtype: bool

# %%
df['passing_math'] = df.math > 70

#will add a new column indicating if the math grade is or is not higher than 70

# %%
df
# Out:
#        name  math  english  reading  passing_math
# 0     Sally    62       85       80         False
# 1      Jane    88       79       67          True
# 2     Suzie    94       74       95          True
# 3     Billy    98       96       88          True
# 4       Ada    77       92       98          True
# 5      John    79       76       93          True
# 6    Thomas    82       64       81          True
# 7     Marie    93       63       90          True
# 8    Albert    92       62       87          True
# 9   Richard    69       80       94         False
# 10    Isaac    92       99       93          True
# 11     Alan    92       62       72          True

# %%
df.assign(passing_english=df.english >= 70)

#you can use .assign() to create another column
# Out:
#        name  math  english  reading  passing_math  passing_english
# 0     Sally    62       85       80         False             True
# 1      Jane    88       79       67          True             True
# 2     Suzie    94       74       95          True             True
# 3     Billy    98       96       88          True             True
# 4       Ada    77       92       98          True             True
# 5      John    79       76       93          True             True
# 6    Thomas    82       64       81          True            False
# 7     Marie    93       63       90          True            False
# 8    Albert    92       62       87          True            False
# 9   Richard    69       80       94         False             True
# 10    Isaac    92       99       93          True             True
# 11     Alan    92       62       72          True            False

# %%
df

# .assign() columns are not saved unless specifically saved to a variable
# Out:
#        name  math  english  reading  passing_math
# 0     Sally    62       85       80         False
# 1      Jane    88       79       67          True
# 2     Suzie    94       74       95          True
# 3     Billy    98       96       88          True
# 4       Ada    77       92       98          True
# 5      John    79       76       93          True
# 6    Thomas    82       64       81          True
# 7     Marie    93       63       90          True
# 8    Albert    92       62       87          True
# 9   Richard    69       80       94         False
# 10    Isaac    92       99       93          True
# 11     Alan    92       62       72          True

# %% [markdown]
# # Sorting Dataframes

# %%
df.sort_values(by='english')

#will sort by the values in the specified column
# Out:
#        name  math  english  reading  passing_math
# 8    Albert    92       62       87          True
# 11     Alan    92       62       72          True
# 7     Marie    93       63       90          True
# 6    Thomas    82       64       81          True
# 2     Suzie    94       74       95          True
# 5      John    79       76       93          True
# 1      Jane    88       79       67          True
# 9   Richard    69       80       94         False
# 0     Sally    62       85       80         False
# 4       Ada    77       92       98          True
# 3     Billy    98       96       88          True
# 10    Isaac    92       99       93          True

# %%
df.sort_values(by='english', ascending=False)
# Out:
#        name  math  english  reading  passing_math
# 10    Isaac    92       99       93          True
# 3     Billy    98       96       88          True
# 4       Ada    77       92       98          True
# 0     Sally    62       85       80         False
# 9   Richard    69       80       94         False
# 1      Jane    88       79       67          True
# 5      John    79       76       93          True
# 2     Suzie    94       74       95          True
# 6    Thomas    82       64       81          True
# 7     Marie    93       63       90          True
# 8    Albert    92       62       87          True
# 11     Alan    92       62       72          True

# %% [markdown]
# # Chaining Dataframe Methods

# %%
df[df.english > 90].sort_values(by='english').head(1).name

#will first sort out all students with english grades above 90, then will proceed to return the lowest one

##you can chain as many methods together as you like so long as syntax is correct
# Out:
# 4    Ada
# Name: name, dtype: object
